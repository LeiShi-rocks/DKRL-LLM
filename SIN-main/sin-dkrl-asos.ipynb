# %% [markdown]
# # Starter

# %%
# %% [code]
import argparse
from datetime import datetime
import torch
import wandb
import logging
import time
import torch.nn.functional as F

import torch
from data.dataset import Dataset 
import logging
from data.dataset import TestUnit, TestUnits, create_pt_geometric_dataset
from torch_geometric.data import Batch

# Import configuration functions and experiment functions.
from configs.run_model import sw, tcga, dkrl
from configs.utils import str2bool
from experiments.logger import create_logger
from experiments.train import train_and_test, training
from experiments.utils import init_seeds, save_run_results

import numpy as np
import pickle
import os

# Adjust these imports to match your repository's structure.
from data.dataset import Dataset, TestUnit, TestUnits
from units_container import UnitsContainer  # Minimal container defined in a separate file

# Dummy parser that simulates argparse.ArgumentParser for our notebook.
class DummyParser:
    def __init__(self):
        self.args = argparse.Namespace()
    def add_argument(self, name, **kwargs):
        # Remove leading dashes for attribute name.
        key = name.lstrip('-')
        # Set the default value if provided.
        default = kwargs.get("default", None)
        setattr(self.args, key, default)
    def parse_args(self):
        return self.args

def get_args() -> (argparse.Namespace, str, str):
    # Set time strings
    TIME_STR = "{:%Y_%m_%d_%H_%M_%S_%f}".format(datetime.now())
    DATE_STR = "{:%Y_%m_%d}".format(datetime.now())
    
    # Create a dummy parser and add basic arguments.
    parser = DummyParser()
    parser.add_argument("--name", type=str, default=TIME_STR)
    parser.add_argument("--task", type=str, default="dkrl", choices=["dkrl", "sw", "tcga"])
    parser.add_argument("--model", type=str, default="sin", choices=["sin", "gnn", "graphite", "cat", "zero"])
    parser.add_argument("--seed", type=int, default=0)
    parser.add_argument("--cuda", type=int, default=0)
    parser.add_argument("--log_interval", type=int, default=50, help="How many batches to wait before logging training status")
    parser.add_argument("--ablation", type=str, default="False")  # We'll use string and convert later if needed.
    parser.add_argument("--data_path", type=str, default="./generated_data/")
    parser.add_argument("--results_path", type=str, default="./results/")
    
    # Now, based on task, call the appropriate add_params function.
    # These functions expect a parser, so we pass our dummy parser.
    if parser.args.task == "sw":
        sw.add_params(parser)
    elif parser.args.task == "tcga":
        tcga.add_params(parser)
    elif parser.args.task == "dkrl":
        dkrl.add_params(parser)
    
    # Return the resulting Namespace.
    return parser.parse_args(), DATE_STR, TIME_STR



def create_dummy_graphs(treatments):
    """
    Create a dummy id_to_graph_dict for treatments.
    Each treatment gets a dummy graph with one node whose features are the treatment vector.
    """
    n = treatments.shape[0]
    id_to_graph = {}
    for i in range(n):
        id_to_graph[i] = {
            "node_features": treatments[i].reshape(1, -1),  # shape: (1, treatment_dim)
            "edges": np.empty((0, 2)),       # no edges
            "edge_types": np.empty((0,))     # no edge types
        }
    return id_to_graph

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# introduce the DKRL algorithm
import numpy as np
from tqdm import tqdm

def DKRL(y, KZ, KX, N, r, penalty, tol, T, wt = 0, verbose = 0):
    """
    Perform an double kernel representation learning.

    Parameters:
    y (numpy.ndarray): Target vector for optimization.
    KZ (numpy.ndarray): Kernel matrix Z.
    KX (numpy.ndarray): Kernel matrix X.
    N (int): Number of rows in U and V matrices.
    r (int): Number of columns in U and V matrices.
    penalty (float): Regularization parameter.
    tol (float): Tolerance for stopping criterion.
    T (int): Maximum number of iterations.
    wt (float): a number between 0 and 1 for adding identity to degenerate kernel matrix
    

    Returns:
    tuple: Final U and V matrices.
    """
    # Initialize U and V matrices randomly
    Ut = np.random.normal(loc=0, scale=1, size=(N, r))
    Vt = np.random.normal(loc=0, scale=1, size=(N, r))

    for iter in tqdm(range(T)):
        # Update U matrix
        VKX = np.repeat(np.dot(Vt.T, KX), repeats=N, axis=0)
        KZZ = np.tile(KZ, (1, r))
        DesignVt = VKX.T * KZZ  # n * (nr)
        Utt = np.linalg.solve(
            np.dot(DesignVt.T, DesignVt) + penalty * np.kron(np.eye(r, dtype=int), (1-wt) * KZ + wt * np.eye(N)),
            np.dot(DesignVt.T, y)
        )
        Utt = Utt.reshape((N, r), order="F")

        # Update V matrix
        UKZ = np.repeat(np.dot(Utt.T, KZ), repeats=N, axis=0)
        KXX = np.tile(KX, (1, r))
        DesignUt = UKZ.T * KXX  # n * (nr)
        Vtt = np.linalg.solve(
            np.dot(DesignUt.T, DesignUt) + penalty * np.kron(np.eye(r, dtype=int), (1-wt) * KX + wt * np.eye(N)),
            np.dot(DesignUt.T, y)
        )
        Vtt = Vtt.reshape((N, r), order="F")

        # Check stopping criterion
        norm_U = np.linalg.norm(Utt - Ut) / (np.linalg.norm(Ut) + 1e-3)
        norm_V = np.linalg.norm(Vtt - Vt) / (np.linalg.norm(Vt) + 1e-3)
        if verbose:
            print(f"Iteration {iter}: norm_U={norm_U}, norm_V={norm_V}")
        
        
        if norm_U < tol and norm_V < tol:
            break

        # Update Ut and Vt
        Ut = Utt
        Vt = Vtt

    y_pred = np.diag(KZ @ Utt @ Vtt.T @ KX)
    return Utt, Vtt, y_pred

def DKRL_pred(U, V, KZ_pred, KX_pred):
    y_pred = np.diag(KZ_pred.T @ U @ V.T @ KX_pred)
    return y_pred

# %% [markdown]
# # Testing

# %%
# population parameters
N = 500
r = 3

# import the text and embeddings

df = pd.read_csv("../ASOS-dataset-sample-main/ASOS-text.csv")  # Replace with your file path
text = np.array(df["text"].tolist())
embeddings = np.loadtxt('../ASOS-dataset-sample-main/asos-embeddings.csv', delimiter=',')

# Randomly sample a subset of text and embeddings for evaluation
# Set a random seed for reproducibility
np.random.seed(2025)
num_actions = 50

# Randomly sample a subset of text and embeddings for evaluation
# Set a random seed for reproducibility
ind = np.arange(len(text))  # Array with 1000 elements
sampled_ind = np.random.choice(ind, size=num_actions, replace=False)

# Randomly sample 100 elements from the array
text = text[sampled_ind]
Z = embeddings[sampled_ind]

# dimension of the embeddings
p = len(Z[1])
print("the dimension of the embeddings is: " + str(len(Z[1])))

sampled_ind_z = np.random.choice(range(num_actions), size=N, replace=True)
Zsub = Z[sampled_ind_z]

# Simulate covariate level features from Gaussian distributions
np.random.seed(2025)

# p = 1000
# Z = np.random.normal(loc=0, scale=1, size=(N, p))
# row_norms_Z = np.linalg.norm(Z, axis=1, keepdims=True)
# Z = Z / row_norms_Z
# sampled_ind = np.random.choice(range(N), size=N, replace=True)
# Z = Z[sampled_ind]

q = 200
X = np.random.normal(loc=0, scale=1, size=(1000, q))
row_norms_X = np.linalg.norm(X, axis=1, keepdims=True)
X = X / row_norms_X
sampled_ind_x = np.random.choice(range(num_actions), size=N, replace=True)
Xsub = X[sampled_ind_x]

# Simulate projection matrix
# generate random projection
np.random.seed(2025)
P = np.random.normal(loc=0, scale=1, size=(p, q))
L, S, Rt = np.linalg.svd(P, full_matrices=False)
Lr = L[:, :r]
Rr = Rt[:r, :].T

# %% [markdown]
# ## SIN

# %%
# SIN
sampled_ind_z = np.random.choice(range(num_actions), size=N, replace=True)
Zsub = Z[sampled_ind_z]
sampled_ind_x = np.random.choice(range(num_actions), size=N, replace=True)
Xsub = X[sampled_ind_x]

# generate the outcome
Zrsub = np.dot(Zsub, Lr) # n*r
Xrsub = np.dot(Xsub, Rr) # n*r
ysub = np.diag(Zrsub @ Xrsub.T) # + 0.01 * np.random.normal(loc = 0, scale = 1, size = N)

# ----- Step 1: Generate X, Z, y -----
np.random.seed(2025)

# X = np.load("./X.npy")
# Z = np.load("./Z.npy")
# y = np.load("./y.npy")

n_samples = Xsub.shape[0]
n_features = Xsub.shape[1]
n_treatment_features = Zsub.shape[1]

# ----- Step 2: Split Data into Training (80%) and Test (20%) Sets -----
split_index = int(0.9 * n_samples)
X_train, X_test = Xsub[:split_index], Xsub[split_index:]
Z_train, Z_test = Zsub[:split_index], Zsub[split_index:]
y_train, y_test = ysub[:split_index], ysub[split_index:]

treatment_ids_train = sampled_ind_z[:split_index]
# For test data, we will assign two treatments per test unit.
N_test = X_test.shape[0]

# ----- Step 3: Create Dummy Arrays for Graph Structure (Edges) -----
edges_train = np.empty((X_train.shape[0], 0))
edge_types_train = np.empty((X_train.shape[0], 0))
# For test data, we'll use the same for each treatment option.
# We'll create dummy arrays for the concatenated test treatments.


# ----- Step 5: Build Training Data as Dictionary-of-Arrays -----
units_train_dict = {
    "features": X_train,         # shape: (n_train, n_features)
    "treatments": Z_train,       # shape: (n_train, n_treatment_features)
    "outcomes": y_train,         # shape: (n_train,)
    "edges": edges_train,        # shape: (n_train, 0)
    "edge_types": edge_types_train  # shape: (n_train, 0)
}
# Wrap training data in our minimal container.
units_train = UnitsContainer(units_train_dict)

in_sample_dataset_dict = {
    "units": units_train,
    "treatment_ids": treatment_ids_train,
    "id_to_graph_dict": create_dummy_graphs(Z_train),
    "outcomes": y_train
}
training_data = Dataset(data_dict=in_sample_dataset_dict)


# ----- for wrapping up a test dataset -----

treatment_ids_test = sampled_ind_z[split_index:]
# For test data, we will assign two treatments per test unit.
N_test = X_test.shape[0]

# ----- Step 3: Create Dummy Arrays for Graph Structure (Edges) -----
edges_test = np.empty((X_test.shape[0], 0))
edge_types_test = np.empty((X_test.shape[0], 0))
# For test data, we'll use the same for each treatment option.
# We'll create dummy arrays for the concatenated test treatments.

# ----- Step 5: Build Training Data as Dictionary-of-Arrays -----
units_test_dict = {
    "features": X_test,         # shape: (n_train, n_features)
    "treatments": Z_test,       # shape: (n_train, n_treatment_features)
    "outcomes": y_test,         # shape: (n_train,)
    "edges": edges_test,        # shape: (n_train, 0)
    "edge_types": edge_types_test  # shape: (n_train, 0)
}
# Wrap training data in our minimal container.
units_test = UnitsContainer(units_test_dict)

out_sample_dataset_dict = {
    "units": units_test,
    "treatment_ids": treatment_ids_test,
    "id_to_graph_dict": create_dummy_graphs(Z_test),
    "outcomes": y_test
}
testing_data = Dataset(data_dict=out_sample_dataset_dict)

# ----- Step 7: Save the Dataset Objects as Pickle Files -----
output_dir = "./generated_data/dkrl/seed-0/bias-0.1/"
os.makedirs(output_dir, exist_ok=True)

with open(os.path.join(output_dir, "in_sample.p"), "wb") as f:
    pickle.dump(training_data, f)
with open(os.path.join(output_dir, "test.p"), "wb") as f:
    pickle.dump(testing_data, f)

print("Training data (Dataset) and test data (Dataset) ready")

# Training model
args, DATE_STR, TIME_STR = get_args()
# Convert ablation to a boolean if necessary
if isinstance(args.ablation, str):
    args.ablation = args.ablation.lower() in ["true", "1", "yes"]

project_name = f"sin_{DATE_STR}-{args.task}" + ("-ABL" if args.ablation else "")
wandb.init(project=project_name, name=f"{args.model}-{args.seed}", config=args)
init_seeds(seed=args.seed)

logger = create_logger("log/%s.log" % args.name)
logger.info(args)

device = torch.device(f"cuda:{args.cuda}" if torch.cuda.is_available() else "cpu")

trained_model = training(args=args, device=device)
print("Got trained model!")

### Training error
"""Predict outcomes on training data and store the predictions in the Dataset object."""
model = trained_model
model.eval()
logging.info("Predicting outcomes on training data...")
units = training_data.get_units() if hasattr(training_data, "get_units") else training_data.data_dict["units"]
treatment_ids = training_data.data_dict["treatment_ids"]
id_to_graph_dict = training_data.data_dict["id_to_graph_dict"]
pt_dataset = create_pt_geometric_dataset(units=units, treatment_graphs=[id_to_graph_dict[i] for i in treatment_ids])
with torch.no_grad():
    batch = Batch.from_data_list(pt_dataset).to(device)
    predicted_outcomes = model.test_prediction(batch).cpu().numpy()

train_error = np.sqrt(np.linalg.norm(y_train - predicted_outcomes)**2 / int(0.9*n_samples)) 

"""Predict outcomes on training data and store the predictions in the Dataset object."""
model = trained_model
model.eval()
logging.info("Predicting outcomes on training data...")
units = testing_data.get_units() if hasattr(testing_data, "get_units") else testing_data.data_dict["units"]
treatment_ids = testing_data.data_dict["treatment_ids"]
id_to_graph_dict = testing_data.data_dict["id_to_graph_dict"]
pt_dataset = create_pt_geometric_dataset(units=units, treatment_graphs=[id_to_graph_dict[i] for i in treatment_ids])
with torch.no_grad():
    batch = Batch.from_data_list(pt_dataset).to(device)
    predicted_outcomes = model.test_prediction(batch).cpu().numpy()
    
test_error = np.sqrt(np.linalg.norm(y_test - predicted_outcomes)**2 / int(0.1*n_samples)) 

print(train_error)
print(test_error)

# %% [markdown]
# ## Kernel methods

# %%
## Kernel methods
# Compute the kernel
KZ = np.dot(Zsub, Zsub.T)
KX = np.dot(Xsub, Xsub.T)
# sigma = 0.01
# pairwise_sq_dists = np.sum(Z**2, axis=1).reshape(-1, 1) + np.sum(Z**2, axis=1) - 2 * np.dot(Z, Z.T)
# KZ = np.exp(-pairwise_sq_dists / (2 * sigma**2))
# pairwise_sq_dists = np.sum(X**2, axis=1).reshape(-1, 1) + np.sum(X**2, axis=1) - 2 * np.dot(X, X.T)
# KX = np.exp(-pairwise_sq_dists / (2 * sigma**2))

KZX = KZ * KX

# Split data into training and testing
N_train = int(0.9 * N)
N_test = int(0.1 * N)

np.random.seed(2025)
train_id = np.random.choice(range(N), size=N_train, replace=False)
test_id = np.array(list(set(range(N)) - set(train_id)))

# training data
KZ_train = KZ[np.ix_(train_id, train_id)]
KX_train = KX[np.ix_(train_id, train_id)]
KZX_train = KZX[np.ix_(train_id, train_id)]
y_train = ysub[train_id]

# testing data
KZ_test = KZ[np.ix_(train_id, test_id)]
KX_test = KX[np.ix_(train_id, test_id)]
KZX_test = KZX[np.ix_(train_id, test_id)]
y_test = ysub[test_id]

# %%
# DKRL
penalty = 1e-2
tol = 5e-2
r = 2
T = 200

U, V, y_hat = DKRL(y_train, KZ_train, KX_train, N_train, r, penalty, tol, T, wt = 0.01)
y_pred = DKRL_pred(U, V, KZ_test, KX_test)
print(np.sqrt(np.linalg.norm(y_train - y_hat)**2/N_train))
print(np.sqrt(np.linalg.norm(y_test - y_pred)**2/N_test))

# %%
# Product kernel
penalty = 5e-1

alpha = np.linalg.solve(KZX_train + penalty * np.eye(N_train), y_train)
y_hat, y_pred = KZX_train @ alpha, KZX_test.T @ alpha
print(np.sqrt(np.linalg.norm(y_train - y_hat)**2 / N_train))
print(np.sqrt(np.linalg.norm(y_test - y_pred)**2 / N_test))

# %% [markdown]
# # Monte Carlo

# %%
def DGP(r):    
    # import the text and embeddings

    df = pd.read_csv("../ASOS-dataset-sample-main/ASOS-text.csv")  # Replace with your file path
    text = np.array(df["text"].tolist())
    embeddings = np.loadtxt('../ASOS-dataset-sample-main/asos-embeddings.csv', delimiter=',')

    # Randomly sample a subset of text and embeddings for evaluation
    # Set a random seed for reproducibility
    np.random.seed(2025)
    num_actions = 50

    # Randomly sample a subset of text and embeddings for evaluation
    # Set a random seed for reproducibility
    ind = np.arange(len(text))  # Array with 1000 elements
    sampled_ind = np.random.choice(ind, size=num_actions, replace=False)

    # Randomly sample 100 elements from the array
    text = text[sampled_ind]
    Z = embeddings[sampled_ind]

    # dimension of the embeddings
    p = len(Z[1])
    print("the dimension of the embeddings is: " + str(len(Z[1])))

    # Simulate covariate level features from Gaussian distributions
    np.random.seed(2025)

    # p = 1000
    # Z = np.random.normal(loc=0, scale=1, size=(N, p))
    # row_norms_Z = np.linalg.norm(Z, axis=1, keepdims=True)
    # Z = Z / row_norms_Z
    # sampled_ind = np.random.choice(range(N), size=N, replace=True)
    # Z = Z[sampled_ind]

    q = 200
    X = np.random.normal(loc=0, scale=1, size=(1000, q))
    row_norms_X = np.linalg.norm(X, axis=1, keepdims=True)
    X = X / row_norms_X

    # Simulate projection matrix
    # generate random projection
    np.random.seed(2025)
    P = np.random.normal(loc=0, scale=1, size=(p, q))
    L, S, Rt = np.linalg.svd(P, full_matrices=False)
    Lr = L[:, :r]
    Rr = Rt[:r, :].T

    return X, Z, num_actions, p, q, Lr, Rr

# %%
def run_simulation(replication, args, r, X, Z, num_actions, Lr, Rr):
    # Set seed for this replication
    np.random.seed(2025 + replication)
    torch.manual_seed(2025 + replication)

    # --- Data Generation ---
    # 
    N = 500
    sampled_ind_z = np.random.choice(range(num_actions), size=N, replace=True)
    Zsub = Z[sampled_ind_z]
    sampled_ind_x = np.random.choice(range(num_actions), size=N, replace=True)
    Xsub = X[sampled_ind_x]

    # generate the outcome
    Zrsub = np.dot(Zsub, Lr) # n*r
    Xrsub = np.dot(Xsub, Rr) # n*r
    ysub = np.diag(Zrsub @ Xrsub.T) + 0.001 * np.random.normal(loc = 0, scale = 1, size = N)

    n_samples = Xsub.shape[0]
    n_features = Xsub.shape[1]
    n_treatment_features = Zsub.shape[1]


    # Optionally, you can subsample or re-index (simulate the original code)
    # For simplicity, we use the whole dataset.
    # --- Split Data ---
    split_index = int(0.9 * n_samples)
    X_train, X_test = Xsub[:split_index], Xsub[split_index:]
    Z_train, Z_test = Zsub[:split_index], Zsub[split_index:]
    y_train, y_test = ysub[:split_index], ysub[split_index:]
    
    treatment_ids_train = np.arange(X_train.shape[0])
    treatment_ids_test = np.arange(X_test.shape[0])
    
    # Create dummy edges
    edges_train = np.empty((X_train.shape[0], 0))
    edge_types_train = np.empty((X_train.shape[0], 0))
    edges_test = np.empty((X_test.shape[0], 0))
    edge_types_test = np.empty((X_test.shape[0], 0))
    
    # Create dummy graphs
    id_to_graph_dict_train = create_dummy_graphs(Z_train)
    id_to_graph_dict_test = create_dummy_graphs(Z_test)
    
    # Build SIN training data:
    units_train_dict = {
        "features": X_train,
        "treatments": Z_train,
        "outcomes": y_train,
        "edges": edges_train,
        "edge_types": edge_types_train
    }
    units_train = UnitsContainer(units_train_dict)
    in_sample_dataset_dict = {
        "units": units_train,
        "treatment_ids": treatment_ids_train,
        "id_to_graph_dict": id_to_graph_dict_train,
        "outcomes": y_train
    }
    sin_training_data = Dataset(data_dict=in_sample_dataset_dict)
    
    # For SIN test data, we keep the same format:
    units_test_dict = {
        "features": X_test,
        "treatments": Z_test,
        "outcomes": y_test,
        "edges": edges_test,
        "edge_types": edge_types_test
    }
    units_test = UnitsContainer(units_test_dict)
    out_sample_dataset_dict = {
        "units": units_test,
        "treatment_ids": treatment_ids_test,
        "id_to_graph_dict": id_to_graph_dict_test,
        "outcomes": y_test
    }
    sin_testing_data = Dataset(data_dict=out_sample_dataset_dict)
    
    # --- SIN method ---
    # Train SIN model (replace training() with your actual training function)
    project_name = f"sin_{DATE_STR}-{args.task}" + ("-ABL" if args.ablation else "")
    wandb.init(project=project_name, name=f"{args.model}-{args.seed}", config=args)
    init_seeds(seed=args.seed)

    start_time = time.time()
    model_sin = training(args=args, device=torch.device("cpu"))
    sin_time = time.time() - start_time
    
    # Predict on training data for SIN
    sin_units_train = sin_training_data.data_dict["units"]
    sin_treatment_ids_train = sin_training_data.data_dict["treatment_ids"]
    sin_id_to_graph_train = sin_training_data.data_dict["id_to_graph_dict"]
    pt_train = create_pt_geometric_dataset(
        units=sin_units_train,
        treatment_graphs=[sin_id_to_graph_train[i] for i in sin_treatment_ids_train],
        outcomes=sin_training_data.data_dict["outcomes"]
    )
    with torch.no_grad():
        batch_train = Batch.from_data_list(pt_train)
        pred_train_sin = model_sin.test_prediction(batch_train).cpu().numpy()
    sin_train_error = np.sqrt(np.linalg.norm(y_train - pred_train_sin)**2 / len(y_train))
    
    sin_units_test = sin_testing_data.data_dict["units"]
    sin_treatment_ids_test = sin_testing_data.data_dict["treatment_ids"]
    sin_id_to_graph_test = sin_testing_data.data_dict["id_to_graph_dict"]
    pt_test = create_pt_geometric_dataset(
        units=sin_units_test,
        treatment_graphs=[sin_id_to_graph_test[i] for i in sin_treatment_ids_test],
        outcomes=sin_testing_data.data_dict["outcomes"]
    )
    with torch.no_grad():
        batch_test = Batch.from_data_list(pt_test)
        pred_test_sin = model_sin.test_prediction(batch_test).cpu().numpy()
    sin_test_error = np.sqrt(np.linalg.norm(y_test - pred_test_sin)**2 / len(y_test))
    
    # --- DKRL method ---
    # For kernel methods, we use the full data (or a subsample) and compute kernel matrices.
    # Here we assume that Xsub, Zsub, ysub are the same as X, Z, y (or use our generated ones).
    # Compute linear kernels:
    KZ = np.dot(Zsub, Zsub.T)
    KX = np.dot(Xsub, Xsub.T)
    KZX = KZ * KX

    # Split data into training and testing
    N = n_samples
    N_train = split_index
    N_test = N - split_index
    # Use train/test indices from the splitting above:
    train_id = np.arange(N_train)
    test_id = np.arange(N_train, N)

    # Training kernel matrices
    KZ_train_kernel = KZ[np.ix_(train_id, train_id)]
    KX_train_kernel = KX[np.ix_(train_id, train_id)]
    KZX_train_kernel = KZX[np.ix_(train_id, train_id)]
    y_train_kernel = y_train

    # Testing kernel matrices (use rows corresponding to training set and columns corresponding to test set)
    KZ_test_kernel = KZ[np.ix_(train_id, test_id)]
    KX_test_kernel = KX[np.ix_(train_id, test_id)]
    KZX_test_kernel = KZX[np.ix_(train_id, test_id)]
    y_test_kernel = y_test

    # DKRL parameters:
    penalty = 1e-2
    tol = 5e-2
    T = 200
    
    start_time = time.time()
    U, V, y_hat_dkrl_train = DKRL(y_train_kernel, KZ_train_kernel, KX_train_kernel, N_train, r, penalty, tol, T, wt=0.01)
    dkrl_time = time.time() - start_time


    y_hat_dkrl_test = DKRL_pred(U, V, KZ_test_kernel, KX_test_kernel)
    dkrl_train_error = np.sqrt(np.linalg.norm(y_train_kernel - y_hat_dkrl_train)**2 / N_train)
    dkrl_test_error = np.sqrt(np.linalg.norm(y_test_kernel - y_hat_dkrl_test)**2 / N_test)

    # --- Product Kernel method ---
    penalty_pk = 1.0

    start_time = time.time()
    alpha = np.linalg.solve(KZX_train_kernel + penalty_pk * np.eye(N_train), y_train_kernel)
    pk_time = time.time() - start_time

    y_hat_pk_train = KZX_train_kernel @ alpha
    y_hat_pk_test = KZX_test_kernel.T @ alpha
    pk_train_error = np.sqrt(np.linalg.norm(y_train_kernel - y_hat_pk_train)**2 / N_train)
    pk_test_error = np.sqrt(np.linalg.norm(y_test_kernel - y_hat_pk_test)**2 / N_test)
    
    results = {
        "sin": {"train_error": sin_train_error, "test_error": sin_test_error, "time": sin_time},
        "dkrl": {"train_error": dkrl_train_error, "test_error": dkrl_test_error, "time": dkrl_time},
        "product_kernel": {"train_error": pk_train_error, "test_error": pk_test_error, "time": pk_time},
        "rank": r
    }
    return results

def aggregate_results(results_list):
    agg = {}
    for method in results_list[0].keys():
        if method == "rank":
            continue
        train_errors = np.array([res[method].get("train_error", np.nan) for res in results_list])
        test_errors = np.array([res[method].get("test_error", np.nan) for res in results_list])
        # For methods that report separate training and test times (SIN), take average of both.
        if "train_time" in results_list[0][method]:
            times = np.array([(res[method]["train_time"] + res[method]["test_time"]) / 2 for res in results_list])
        else:
            times = np.array([res[method]["time"] for res in results_list])
        agg[method] = {
            "train_error_mean": np.mean(train_errors),
            "train_error_std": np.std(train_errors),
            "test_error_mean": np.mean(test_errors),
            "test_error_std": np.std(test_errors),
            "time_mean": np.mean(times),
            "time_std": np.std(times),
        }
    return agg

# %%
ranks = [2, 3, 5, 10]
num_replications = 100
all_results = {}

args, DATE_STR, TIME_STR = get_args()

# %%
for r in ranks:
    print(f"Running Monte Carlo simulation for rank: {r}")
    results_sample = []
    X, Z, num_actions, p, q, Lr, Rr = DGP(r)
    for rep in range(num_replications):
        print(f"  Replication {rep+1}/{num_replications}")
        res = run_simulation(rep, args, r, X, Z, num_actions, Lr, Rr)
        results_sample.append(res)
    all_results[r] = results_sample

np.save("test-over-rank-asos.npy", all_results)

# %%
all_results = np.load("test-over-rank-asos.npy", allow_pickle=True)

# %%
all_results.item()[2]
# Out:
# [{'sin': {'train_error': np.float64(0.00909844862153716),
#    'test_error': np.float64(0.007565073715095464),
#    'time': 8.92376708984375},
#   'dkrl': {'train_error': np.float64(0.0021279302463975184),
#    'test_error': np.float64(0.002841777063708204),
#    'time': 0.13327884674072266},
#   'product_kernel': {'train_error': np.float64(0.0035883074058660216),
#    'test_error': np.float64(0.005208105995023707),
#    'time': 0.001363992691040039},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009559664501746622),
#    'test_error': np.float64(0.009856708005970778),
#    'time': 9.033508062362671},
#   'dkrl': {'train_error': np.float64(0.0019329231242428643),
#    'test_error': np.float64(0.003150793734233799),
#    'time': 0.29019904136657715},
#   'product_kernel': {'train_error': np.float64(0.0038562310706362294),
#    'test_error': np.float64(0.006907583585080797),
#    'time': 0.0011358261108398438},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00958573866229899),
#    'test_error': np.float64(0.009340501358257028),
#    'time': 8.95636796951294},
#   'dkrl': {'train_error': np.float64(0.002205926487061764),
#    'test_error': np.float64(0.0039074805547774216),
#    'time': 0.18437719345092773},
#   'product_kernel': {'train_error': np.float64(0.0036434609990895657),
#    'test_error': np.float64(0.006508921881735988),
#    'time': 0.0013949871063232422},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00930436067025525),
#    'test_error': np.float64(0.010845002818821519),
#    'time': 8.000779867172241},
#   'dkrl': {'train_error': np.float64(0.0021850017217460186),
#    'test_error': np.float64(0.0027206940068114204),
#    'time': 0.16976189613342285},
#   'product_kernel': {'train_error': np.float64(0.0036785539610571702),
#    'test_error': np.float64(0.005208133909217422),
#    'time': 0.0014650821685791016},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009275152683645503),
#    'test_error': np.float64(0.008757703316120777),
#    'time': 7.674538850784302},
#   'dkrl': {'train_error': np.float64(0.0021827441221830765),
#    'test_error': np.float64(0.003883935244152157),
#    'time': 0.1543881893157959},
#   'product_kernel': {'train_error': np.float64(0.003426678631092451),
#    'test_error': np.float64(0.006256012965022398),
#    'time': 0.00133514404296875},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.010050986274839266),
#    'test_error': np.float64(0.009385858464192983),
#    'time': 7.645510911941528},
#   'dkrl': {'train_error': np.float64(0.0021838892670219424),
#    'test_error': np.float64(0.002932116067326539),
#    'time': 0.17176508903503418},
#   'product_kernel': {'train_error': np.float64(0.0037235706706374183),
#    'test_error': np.float64(0.006851427687508176),
#    'time': 0.0013532638549804688},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009360669677011574),
#    'test_error': np.float64(0.009156271520885276),
#    'time': 7.560314655303955},
#   'dkrl': {'train_error': np.float64(0.0019667070839000348),
#    'test_error': np.float64(0.0024516526351330043),
#    'time': 0.1503429412841797},
#   'product_kernel': {'train_error': np.float64(0.003715625115413989),
#    'test_error': np.float64(0.005901123845400627),
#    'time': 0.0018310546875},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009077010915198755),
#    'test_error': np.float64(0.008573716449828352),
#    'time': 7.842375993728638},
#   'dkrl': {'train_error': np.float64(0.002168306421893524),
#    'test_error': np.float64(0.003070365938439024),
#    'time': 0.15048980712890625},
#   'product_kernel': {'train_error': np.float64(0.003639411914760168),
#    'test_error': np.float64(0.004496314828461412),
#    'time': 0.0011889934539794922},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009821516857553293),
#    'test_error': np.float64(0.01234776370126383),
#    'time': 8.008596897125244},
#   'dkrl': {'train_error': np.float64(0.0023608928315903754),
#    'test_error': np.float64(0.004015053231622547),
#    'time': 0.1521139144897461},
#   'product_kernel': {'train_error': np.float64(0.0035469336883179148),
#    'test_error': np.float64(0.0072397489932218536),
#    'time': 0.0013208389282226562},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009536426214408974),
#    'test_error': np.float64(0.009648314465198527),
#    'time': 7.40234112739563},
#   'dkrl': {'train_error': np.float64(0.002184814782154848),
#    'test_error': np.float64(0.002549370535947073),
#    'time': 0.1708211898803711},
#   'product_kernel': {'train_error': np.float64(0.0037929840858054297),
#    'test_error': np.float64(0.005064462419226218),
#    'time': 0.0014081001281738281},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009210018042382119),
#    'test_error': np.float64(0.006996757327996864),
#    'time': 7.35089898109436},
#   'dkrl': {'train_error': np.float64(0.0021887983079878614),
#    'test_error': np.float64(0.0026837176803045045),
#    'time': 0.2029588222503662},
#   'product_kernel': {'train_error': np.float64(0.0037723190128399592),
#    'test_error': np.float64(0.00426709796933552),
#    'time': 0.0011472702026367188},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009118050280789852),
#    'test_error': np.float64(0.009573739497780637),
#    'time': 7.391391038894653},
#   'dkrl': {'train_error': np.float64(0.0023257767014555927),
#    'test_error': np.float64(0.0037199895593014605),
#    'time': 0.17040514945983887},
#   'product_kernel': {'train_error': np.float64(0.0034060572275108),
#    'test_error': np.float64(0.006984050635081467),
#    'time': 0.0011620521545410156},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.010011147883829256),
#    'test_error': np.float64(0.007892573673662811),
#    'time': 7.779024839401245},
#   'dkrl': {'train_error': np.float64(0.002161193003760206),
#    'test_error': np.float64(0.003146083095865283),
#    'time': 0.17433500289916992},
#   'product_kernel': {'train_error': np.float64(0.0039417783694658684),
#    'test_error': np.float64(0.0037567023666841195),
#    'time': 0.0011649131774902344},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008864347241053458),
#    'test_error': np.float64(0.00963266211653419),
#    'time': 7.822484970092773},
#   'dkrl': {'train_error': np.float64(0.0021307995969762784),
#    'test_error': np.float64(0.0036018308896086514),
#    'time': 0.1497209072113037},
#   'product_kernel': {'train_error': np.float64(0.0033441216680030706),
#    'test_error': np.float64(0.005880958724299707),
#    'time': 0.001329183578491211},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009892065543449884),
#    'test_error': np.float64(0.010161216714036893),
#    'time': 7.777864217758179},
#   'dkrl': {'train_error': np.float64(0.0021774551052132353),
#    'test_error': np.float64(0.003472624281015209),
#    'time': 0.12517285346984863},
#   'product_kernel': {'train_error': np.float64(0.0036985325978968354),
#    'test_error': np.float64(0.006066713631980074),
#    'time': 0.0011909008026123047},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009913809475642863),
#    'test_error': np.float64(0.00963603758301576),
#    'time': 7.815985202789307},
#   'dkrl': {'train_error': np.float64(0.002137467663658213),
#    'test_error': np.float64(0.0036781126798816764),
#    'time': 0.17430615425109863},
#   'product_kernel': {'train_error': np.float64(0.003862170239394886),
#    'test_error': np.float64(0.005905514541810321),
#    'time': 0.0012600421905517578},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009140772243968831),
#    'test_error': np.float64(0.010659183461589398),
#    'time': 7.675379991531372},
#   'dkrl': {'train_error': np.float64(0.002168063377439444),
#    'test_error': np.float64(0.005548180936795379),
#    'time': 0.17096710205078125},
#   'product_kernel': {'train_error': np.float64(0.0035513114888217324),
#    'test_error': np.float64(0.008222709449104778),
#    'time': 0.0014867782592773438},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009246881306427954),
#    'test_error': np.float64(0.010618066736957577),
#    'time': 7.664828777313232},
#   'dkrl': {'train_error': np.float64(0.0021967311568777213),
#    'test_error': np.float64(0.003341054100070499),
#    'time': 0.17449498176574707},
#   'product_kernel': {'train_error': np.float64(0.003562401488240291),
#    'test_error': np.float64(0.006039961045169062),
#    'time': 0.0014832019805908203},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009629787481905468),
#    'test_error': np.float64(0.009020112286606508),
#    'time': 7.476327180862427},
#   'dkrl': {'train_error': np.float64(0.0020517443463222273),
#    'test_error': np.float64(0.0032150704673597945),
#    'time': 0.20229506492614746},
#   'product_kernel': {'train_error': np.float64(0.003947862254878093),
#    'test_error': np.float64(0.006217386837076792),
#    'time': 0.0010700225830078125},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009070061453120547),
#    'test_error': np.float64(0.010981682996416688),
#    'time': 7.7003867626190186},
#   'dkrl': {'train_error': np.float64(0.001976542796505221),
#    'test_error': np.float64(0.0035786893855328044),
#    'time': 0.1503157615661621},
#   'product_kernel': {'train_error': np.float64(0.0036526070797401424),
#    'test_error': np.float64(0.0071532581751720375),
#    'time': 0.0012841224670410156},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009578526868278803),
#    'test_error': np.float64(0.00989235443812745),
#    'time': 7.43702507019043},
#   'dkrl': {'train_error': np.float64(0.0022469733616176228),
#    'test_error': np.float64(0.0046275795604734824),
#    'time': 0.22494792938232422},
#   'product_kernel': {'train_error': np.float64(0.003388240320919521),
#    'test_error': np.float64(0.006844094090583776),
#    'time': 0.0012431144714355469},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00884877427436449),
#    'test_error': np.float64(0.009759590748451992),
#    'time': 7.60561203956604},
#   'dkrl': {'train_error': np.float64(0.0021215907579917146),
#    'test_error': np.float64(0.00266148623290451),
#    'time': 0.21018004417419434},
#   'product_kernel': {'train_error': np.float64(0.0035475929225848935),
#    'test_error': np.float64(0.00644968385622675),
#    'time': 0.0012431144714355469},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009748224017603387),
#    'test_error': np.float64(0.011323754322362727),
#    'time': 7.711462020874023},
#   'dkrl': {'train_error': np.float64(0.0019417265615146884),
#    'test_error': np.float64(0.0029618478297535476),
#    'time': 0.1534438133239746},
#   'product_kernel': {'train_error': np.float64(0.0036434858936800043),
#    'test_error': np.float64(0.0071633909435138594),
#    'time': 0.0012211799621582031},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009462536670208707),
#    'test_error': np.float64(0.008328669660698968),
#    'time': 7.741558074951172},
#   'dkrl': {'train_error': np.float64(0.0021355463674377555),
#    'test_error': np.float64(0.0039069225084403655),
#    'time': 0.23177003860473633},
#   'product_kernel': {'train_error': np.float64(0.003348297385139893),
#    'test_error': np.float64(0.00711732544137893),
#    'time': 0.0012500286102294922},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.010079190276416843),
#    'test_error': np.float64(0.009412670610312078),
#    'time': 7.685204982757568},
#   'dkrl': {'train_error': np.float64(0.0020697080503095625),
#    'test_error': np.float64(0.002831592093236836),
#    'time': 0.17461085319519043},
#   'product_kernel': {'train_error': np.float64(0.0037930893506747006),
#    'test_error': np.float64(0.00638152189153165),
#    'time': 0.0013928413391113281},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008716619918695434),
#    'test_error': np.float64(0.010990166765209844),
#    'time': 7.750664949417114},
#   'dkrl': {'train_error': np.float64(0.002188090616972459),
#    'test_error': np.float64(0.0035996720484601057),
#    'time': 0.15576982498168945},
#   'product_kernel': {'train_error': np.float64(0.0034015284258534606),
#    'test_error': np.float64(0.00663512676997616),
#    'time': 0.0011429786682128906},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009322120087663812),
#    'test_error': np.float64(0.009261770322382104),
#    'time': 7.675436973571777},
#   'dkrl': {'train_error': np.float64(0.0020566053329180638),
#    'test_error': np.float64(0.0022679045213232596),
#    'time': 0.15309691429138184},
#   'product_kernel': {'train_error': np.float64(0.003567222595081035),
#    'test_error': np.float64(0.005407848694461234),
#    'time': 0.0013179779052734375},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009567096747756892),
#    'test_error': np.float64(0.009314015780235446),
#    'time': 7.816671133041382},
#   'dkrl': {'train_error': np.float64(0.002194946457153986),
#    'test_error': np.float64(0.0031912435075996354),
#    'time': 0.17033004760742188},
#   'product_kernel': {'train_error': np.float64(0.0036500507101474367),
#    'test_error': np.float64(0.006442540249364457),
#    'time': 0.001233816146850586},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008978631544853512),
#    'test_error': np.float64(0.009449129126355713),
#    'time': 8.042019128799438},
#   'dkrl': {'train_error': np.float64(0.002195353886537703),
#    'test_error': np.float64(0.0036519319867418425),
#    'time': 0.24560308456420898},
#   'product_kernel': {'train_error': np.float64(0.003390268929639503),
#    'test_error': np.float64(0.00647851489754133),
#    'time': 0.0012359619140625},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009312723485166319),
#    'test_error': np.float64(0.00913368689153047),
#    'time': 7.672330856323242},
#   'dkrl': {'train_error': np.float64(0.0021811536387620505),
#    'test_error': np.float64(0.0038715836236493046),
#    'time': 0.16895723342895508},
#   'product_kernel': {'train_error': np.float64(0.003368036547435858),
#    'test_error': np.float64(0.006809362421414174),
#    'time': 0.0011951923370361328},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009097259618706272),
#    'test_error': np.float64(0.009490975742973987),
#    'time': 8.363813877105713},
#   'dkrl': {'train_error': np.float64(0.0021480824519946257),
#    'test_error': np.float64(0.002285616794619198),
#    'time': 0.1578199863433838},
#   'product_kernel': {'train_error': np.float64(0.003611742789091203),
#    'test_error': np.float64(0.004972658992884462),
#    'time': 0.0015060901641845703},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009808350768271792),
#    'test_error': np.float64(0.010120224727881409),
#    'time': 7.841825008392334},
#   'dkrl': {'train_error': np.float64(0.0021503238341514523),
#    'test_error': np.float64(0.0038616006852517856),
#    'time': 0.17914795875549316},
#   'product_kernel': {'train_error': np.float64(0.003868866390900183),
#    'test_error': np.float64(0.006018035575283609),
#    'time': 0.0013582706451416016},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00901266775615142),
#    'test_error': np.float64(0.007710796845027322),
#    'time': 7.585067987442017},
#   'dkrl': {'train_error': np.float64(0.0023165089501318856),
#    'test_error': np.float64(0.004015328316106742),
#    'time': 0.1504349708557129},
#   'product_kernel': {'train_error': np.float64(0.0035783800504943196),
#    'test_error': np.float64(0.00593898484992869),
#    'time': 0.0011959075927734375},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.010001099486212061),
#    'test_error': np.float64(0.010133446135590056),
#    'time': 7.78049898147583},
#   'dkrl': {'train_error': np.float64(0.0021982772913496785),
#    'test_error': np.float64(0.003191601455627384),
#    'time': 0.1796281337738037},
#   'product_kernel': {'train_error': np.float64(0.0037044735107854914),
#    'test_error': np.float64(0.007178690801424094),
#    'time': 0.0013391971588134766},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009535848886651193),
#    'test_error': np.float64(0.01098156992180092),
#    'time': 7.948925018310547},
#   'dkrl': {'train_error': np.float64(0.0022555825748066718),
#    'test_error': np.float64(0.00344975655946796),
#    'time': 0.16179823875427246},
#   'product_kernel': {'train_error': np.float64(0.003560392337164718),
#    'test_error': np.float64(0.007573089781143988),
#    'time': 0.0015039443969726562},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009333050395423356),
#    'test_error': np.float64(0.010907938375056532),
#    'time': 7.942920923233032},
#   'dkrl': {'train_error': np.float64(0.0021277587892587677),
#    'test_error': np.float64(0.0035265620297166085),
#    'time': 0.18395400047302246},
#   'product_kernel': {'train_error': np.float64(0.0036608896534573005),
#    'test_error': np.float64(0.006945159775202541),
#    'time': 0.001378774642944336},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009578452787658308),
#    'test_error': np.float64(0.010712409874303599),
#    'time': 7.901915073394775},
#   'dkrl': {'train_error': np.float64(0.0020291228001101994),
#    'test_error': np.float64(0.0038524277858378387),
#    'time': 0.1508958339691162},
#   'product_kernel': {'train_error': np.float64(0.003622960880454922),
#    'test_error': np.float64(0.006428774091025593),
#    'time': 0.0013439655303955078},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00915756205216629),
#    'test_error': np.float64(0.008543821232893477),
#    'time': 7.443835973739624},
#   'dkrl': {'train_error': np.float64(0.0020251431969085963),
#    'test_error': np.float64(0.003585452235077631),
#    'time': 0.15432405471801758},
#   'product_kernel': {'train_error': np.float64(0.0034360119998254873),
#    'test_error': np.float64(0.006842044207750867),
#    'time': 0.0011949539184570312},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009311190872531176),
#    'test_error': np.float64(0.008175166498971789),
#    'time': 7.489727020263672},
#   'dkrl': {'train_error': np.float64(0.0021886308573004403),
#    'test_error': np.float64(0.002940882605228119),
#    'time': 0.20635175704956055},
#   'product_kernel': {'train_error': np.float64(0.0035440180490444663),
#    'test_error': np.float64(0.0050431206804489054),
#    'time': 0.0014109611511230469},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008644668776306905),
#    'test_error': np.float64(0.010678897388515832),
#    'time': 7.881680965423584},
#   'dkrl': {'train_error': np.float64(0.001964879051263402),
#    'test_error': np.float64(0.003132276430802304),
#    'time': 0.16163086891174316},
#   'product_kernel': {'train_error': np.float64(0.0033879920045702338),
#    'test_error': np.float64(0.0076011673049816535),
#    'time': 0.0012209415435791016},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00953946611369268),
#    'test_error': np.float64(0.009921488822808825),
#    'time': 7.7846598625183105},
#   'dkrl': {'train_error': np.float64(0.0022371220904721647),
#    'test_error': np.float64(0.004396746687902933),
#    'time': 0.12581205368041992},
#   'product_kernel': {'train_error': np.float64(0.003661760228915752),
#    'test_error': np.float64(0.008132959690695364),
#    'time': 0.0012059211730957031},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.0091735554548079),
#    'test_error': np.float64(0.010077014817215383),
#    'time': 7.96736216545105},
#   'dkrl': {'train_error': np.float64(0.002267730307337258),
#    'test_error': np.float64(0.00510014421158256),
#    'time': 0.15366005897521973},
#   'product_kernel': {'train_error': np.float64(0.003629610670588674),
#    'test_error': np.float64(0.008852521276094403),
#    'time': 0.0013308525085449219},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009431977544026247),
#    'test_error': np.float64(0.010609291862649192),
#    'time': 7.830886363983154},
#   'dkrl': {'train_error': np.float64(0.0021627785655934373),
#    'test_error': np.float64(0.0038391643071424898),
#    'time': 0.1803290843963623},
#   'product_kernel': {'train_error': np.float64(0.003405819860441689),
#    'test_error': np.float64(0.005582578556252291),
#    'time': 0.0014731884002685547},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008992620541288838),
#    'test_error': np.float64(0.007936704214810686),
#    'time': 7.523226022720337},
#   'dkrl': {'train_error': np.float64(0.0021192915158350233),
#    'test_error': np.float64(0.0036379842597381836),
#    'time': 0.303682804107666},
#   'product_kernel': {'train_error': np.float64(0.0033402854847354585),
#    'test_error': np.float64(0.006429256365751697),
#    'time': 0.0011348724365234375},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009432661167196061),
#    'test_error': np.float64(0.010336718202275417),
#    'time': 7.826651096343994},
#   'dkrl': {'train_error': np.float64(0.002055206011183183),
#    'test_error': np.float64(0.0035168119988966745),
#    'time': 0.1564481258392334},
#   'product_kernel': {'train_error': np.float64(0.00358072045274748),
#    'test_error': np.float64(0.0069606160803796025),
#    'time': 0.0012118816375732422},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009197590116745199),
#    'test_error': np.float64(0.009695836428142441),
#    'time': 8.498836994171143},
#   'dkrl': {'train_error': np.float64(0.0023770365024207655),
#    'test_error': np.float64(0.003136066084164935),
#    'time': 0.14798212051391602},
#   'product_kernel': {'train_error': np.float64(0.003568209863885689),
#    'test_error': np.float64(0.005206260268855514),
#    'time': 0.0014557838439941406},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009414512127855322),
#    'test_error': np.float64(0.008134169244388293),
#    'time': 7.921186208724976},
#   'dkrl': {'train_error': np.float64(0.002281205619827177),
#    'test_error': np.float64(0.0032171884086284667),
#    'time': 0.15924715995788574},
#   'product_kernel': {'train_error': np.float64(0.0037291556971289857),
#    'test_error': np.float64(0.0059901994973371835),
#    'time': 0.0011909008026123047},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009651913004450896),
#    'test_error': np.float64(0.008660058567150115),
#    'time': 7.303431987762451},
#   'dkrl': {'train_error': np.float64(0.002170625500019603),
#    'test_error': np.float64(0.002697621915485642),
#    'time': 0.1769721508026123},
#   'product_kernel': {'train_error': np.float64(0.0035930091998747473),
#    'test_error': np.float64(0.0055809231383932975),
#    'time': 0.001209259033203125},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008892349185156597),
#    'test_error': np.float64(0.008577362983921717),
#    'time': 7.680943012237549},
#   'dkrl': {'train_error': np.float64(0.002156772172015287),
#    'test_error': np.float64(0.0023648122531377005),
#    'time': 0.15066075325012207},
#   'product_kernel': {'train_error': np.float64(0.0035691782403374055),
#    'test_error': np.float64(0.00460010728140618),
#    'time': 0.0012660026550292969},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008483327554553196),
#    'test_error': np.float64(0.008555132723267767),
#    'time': 7.763068914413452},
#   'dkrl': {'train_error': np.float64(0.0022123834989366785),
#    'test_error': np.float64(0.004102891631078344),
#    'time': 0.2259228229522705},
#   'product_kernel': {'train_error': np.float64(0.0033917147273668123),
#    'test_error': np.float64(0.007002698798925042),
#    'time': 0.0013427734375},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009163344561483731),
#    'test_error': np.float64(0.00872878164428963),
#    'time': 7.656925201416016},
#   'dkrl': {'train_error': np.float64(0.002125885830237906),
#    'test_error': np.float64(0.0033331279904673826),
#    'time': 0.2462327480316162},
#   'product_kernel': {'train_error': np.float64(0.0035340602720416326),
#    'test_error': np.float64(0.006792124832303483),
#    'time': 0.0016796588897705078},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009203839237036077),
#    'test_error': np.float64(0.009991931827341346),
#    'time': 7.56499719619751},
#   'dkrl': {'train_error': np.float64(0.0022978333057792977),
#    'test_error': np.float64(0.0033299648835836164),
#    'time': 0.18106698989868164},
#   'product_kernel': {'train_error': np.float64(0.0037199826621568516),
#    'test_error': np.float64(0.005638515558024867),
#    'time': 0.0012149810791015625},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009163278886970702),
#    'test_error': np.float64(0.009776611362480297),
#    'time': 7.799256801605225},
#   'dkrl': {'train_error': np.float64(0.002207869073027038),
#    'test_error': np.float64(0.005695113449847017),
#    'time': 0.20107698440551758},
#   'product_kernel': {'train_error': np.float64(0.003455573261068982),
#    'test_error': np.float64(0.008026731985318756),
#    'time': 0.0013632774353027344},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009396528022301868),
#    'test_error': np.float64(0.011776725683718363),
#    'time': 8.987482070922852},
#   'dkrl': {'train_error': np.float64(0.0021133309480745716),
#    'test_error': np.float64(0.0027023020355957834),
#    'time': 0.1832900047302246},
#   'product_kernel': {'train_error': np.float64(0.0037835715169718094),
#    'test_error': np.float64(0.0059317084726540105),
#    'time': 0.0012118816375732422},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009173591503702758),
#    'test_error': np.float64(0.008510727781693511),
#    'time': 8.52440595626831},
#   'dkrl': {'train_error': np.float64(0.0021782365465542537),
#    'test_error': np.float64(0.0029161212140203377),
#    'time': 0.1776719093322754},
#   'product_kernel': {'train_error': np.float64(0.0037030492856638727),
#    'test_error': np.float64(0.005076082125542506),
#    'time': 0.0011830329895019531},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009852718393193287),
#    'test_error': np.float64(0.011445371386271788),
#    'time': 8.26297116279602},
#   'dkrl': {'train_error': np.float64(0.002397260003780726),
#    'test_error': np.float64(0.003831401708393455),
#    'time': 0.14915204048156738},
#   'product_kernel': {'train_error': np.float64(0.0037931115501521465),
#    'test_error': np.float64(0.006788482862423881),
#    'time': 0.0012149810791015625},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00900852985961446),
#    'test_error': np.float64(0.009026086845427436),
#    'time': 8.113908052444458},
#   'dkrl': {'train_error': np.float64(0.002284608746126236),
#    'test_error': np.float64(0.004158058381963685),
#    'time': 0.1486499309539795},
#   'product_kernel': {'train_error': np.float64(0.0035757057773121393),
#    'test_error': np.float64(0.00634678768068939),
#    'time': 0.0019850730895996094},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.010449745269527631),
#    'test_error': np.float64(0.00819622201158071),
#    'time': 7.817410945892334},
#   'dkrl': {'train_error': np.float64(0.00216405669865972),
#    'test_error': np.float64(0.0023497322200672884),
#    'time': 0.22299981117248535},
#   'product_kernel': {'train_error': np.float64(0.003705894902532639),
#    'test_error': np.float64(0.0045173807389145264),
#    'time': 0.0012030601501464844},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009543942723843594),
#    'test_error': np.float64(0.008101671811854191),
#    'time': 8.061282873153687},
#   'dkrl': {'train_error': np.float64(0.002076259045799473),
#    'test_error': np.float64(0.002675371491071902),
#    'time': 0.2000288963317871},
#   'product_kernel': {'train_error': np.float64(0.0038825403595058004),
#    'test_error': np.float64(0.005356803868687065),
#    'time': 0.001394033432006836},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009917474241360193),
#    'test_error': np.float64(0.01009221281802753),
#    'time': 7.640955924987793},
#   'dkrl': {'train_error': np.float64(0.0022432666101288),
#    'test_error': np.float64(0.00399679193182568),
#    'time': 0.18629813194274902},
#   'product_kernel': {'train_error': np.float64(0.0037390090066395758),
#    'test_error': np.float64(0.006176370425875996),
#    'time': 0.0012619495391845703},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009119754738642688),
#    'test_error': np.float64(0.009644139476944272),
#    'time': 8.399384021759033},
#   'dkrl': {'train_error': np.float64(0.0020416007057301173),
#    'test_error': np.float64(0.003153831568545761),
#    'time': 0.19499897956848145},
#   'product_kernel': {'train_error': np.float64(0.003556760366266306),
#    'test_error': np.float64(0.006335918622776123),
#    'time': 0.0013079643249511719},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.010050885324969198),
#    'test_error': np.float64(0.008084391534626003),
#    'time': 7.932714939117432},
#   'dkrl': {'train_error': np.float64(0.002103650288722283),
#    'test_error': np.float64(0.0031030848863408487),
#    'time': 0.15657806396484375},
#   'product_kernel': {'train_error': np.float64(0.003682717777747813),
#    'test_error': np.float64(0.004920140434011921),
#    'time': 0.0013592243194580078},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009202676210961765),
#    'test_error': np.float64(0.009842032885341833),
#    'time': 7.809831142425537},
#   'dkrl': {'train_error': np.float64(0.0020213446780341475),
#    'test_error': np.float64(0.003194304297711536),
#    'time': 0.15332388877868652},
#   'product_kernel': {'train_error': np.float64(0.0036796703218398745),
#    'test_error': np.float64(0.00640152599940876),
#    'time': 0.001661062240600586},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009217232483128262),
#    'test_error': np.float64(0.010460452291858878),
#    'time': 7.866821765899658},
#   'dkrl': {'train_error': np.float64(0.0020929413478191043),
#    'test_error': np.float64(0.003190225910914801),
#    'time': 0.15702009201049805},
#   'product_kernel': {'train_error': np.float64(0.00361561336920848),
#    'test_error': np.float64(0.007067185188823242),
#    'time': 0.0016987323760986328},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008803849410543487),
#    'test_error': np.float64(0.007969189653081663),
#    'time': 7.885697841644287},
#   'dkrl': {'train_error': np.float64(0.002049918191923507),
#    'test_error': np.float64(0.0037105353448149627),
#    'time': 0.15575194358825684},
#   'product_kernel': {'train_error': np.float64(0.0033184083651829296),
#    'test_error': np.float64(0.006495861828893285),
#    'time': 0.0013539791107177734},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009844917941806726),
#    'test_error': np.float64(0.009655248164970646),
#    'time': 7.746037244796753},
#   'dkrl': {'train_error': np.float64(0.002271381197019937),
#    'test_error': np.float64(0.002920857418553033),
#    'time': 0.15259075164794922},
#   'product_kernel': {'train_error': np.float64(0.003537990519552722),
#    'test_error': np.float64(0.005068166866220868),
#    'time': 0.0013837814331054688},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009017685626842515),
#    'test_error': np.float64(0.009929875737131236),
#    'time': 8.044931650161743},
#   'dkrl': {'train_error': np.float64(0.002005299278127731),
#    'test_error': np.float64(0.003179639210488987),
#    'time': 0.14942002296447754},
#   'product_kernel': {'train_error': np.float64(0.0036266915715118743),
#    'test_error': np.float64(0.0057897170432853855),
#    'time': 0.0014300346374511719},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00897129750451002),
#    'test_error': np.float64(0.010609455495333752),
#    'time': 8.042563676834106},
#   'dkrl': {'train_error': np.float64(0.0022754203963770187),
#    'test_error': np.float64(0.003147425935589301),
#    'time': 0.1575469970703125},
#   'product_kernel': {'train_error': np.float64(0.0033977505319894895),
#    'test_error': np.float64(0.005745757166309591),
#    'time': 0.0011970996856689453},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009097013600044572),
#    'test_error': np.float64(0.01025422874394021),
#    'time': 7.570605039596558},
#   'dkrl': {'train_error': np.float64(0.002185776286814297),
#    'test_error': np.float64(0.003373939489443103),
#    'time': 0.17192387580871582},
#   'product_kernel': {'train_error': np.float64(0.003625317388804057),
#    'test_error': np.float64(0.004626908373019282),
#    'time': 0.0012767314910888672},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009294237226521352),
#    'test_error': np.float64(0.009561717871443508),
#    'time': 7.975414037704468},
#   'dkrl': {'train_error': np.float64(0.002175755486513154),
#    'test_error': np.float64(0.003918342966498152),
#    'time': 0.17569708824157715},
#   'product_kernel': {'train_error': np.float64(0.003514040792433527),
#    'test_error': np.float64(0.0066392165647867615),
#    'time': 0.0012722015380859375},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.0097646791990036),
#    'test_error': np.float64(0.010084015105067217),
#    'time': 7.94174599647522},
#   'dkrl': {'train_error': np.float64(0.002022979510655843),
#    'test_error': np.float64(0.0028530433504350703),
#    'time': 0.1330397129058838},
#   'product_kernel': {'train_error': np.float64(0.003732480284030902),
#    'test_error': np.float64(0.006076196473810431),
#    'time': 0.0014090538024902344},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008821277213410254),
#    'test_error': np.float64(0.012445223886064989),
#    'time': 8.070976972579956},
#   'dkrl': {'train_error': np.float64(0.0022450702478084895),
#    'test_error': np.float64(0.004143509674813683),
#    'time': 0.23806309700012207},
#   'product_kernel': {'train_error': np.float64(0.00361554633605805),
#    'test_error': np.float64(0.00790644711858113),
#    'time': 0.001332998275756836},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.010088501781733565),
#    'test_error': np.float64(0.00859209000662196),
#    'time': 7.639477014541626},
#   'dkrl': {'train_error': np.float64(0.002365295165429427),
#    'test_error': np.float64(0.0038226398598788965),
#    'time': 0.19371485710144043},
#   'product_kernel': {'train_error': np.float64(0.0035263297714417476),
#    'test_error': np.float64(0.005053609125643531),
#    'time': 0.0014657974243164062},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009120027654308981),
#    'test_error': np.float64(0.008043351572917976),
#    'time': 7.86733078956604},
#   'dkrl': {'train_error': np.float64(0.0021528537328752285),
#    'test_error': np.float64(0.0031350783147987356),
#    'time': 0.1774158477783203},
#   'product_kernel': {'train_error': np.float64(0.0037397414633382805),
#    'test_error': np.float64(0.006164514059144639),
#    'time': 0.0011959075927734375},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009712929849204494),
#    'test_error': np.float64(0.00993339130778716),
#    'time': 7.828644752502441},
#   'dkrl': {'train_error': np.float64(0.0019824261875176653),
#    'test_error': np.float64(0.0033412064301350515),
#    'time': 0.14625096321105957},
#   'product_kernel': {'train_error': np.float64(0.0036012487006873758),
#    'test_error': np.float64(0.006080578027319098),
#    'time': 0.0012369155883789062},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009714980569375576),
#    'test_error': np.float64(0.009020055547028843),
#    'time': 7.8992018699646},
#   'dkrl': {'train_error': np.float64(0.0020030735560693184),
#    'test_error': np.float64(0.003091269931210565),
#    'time': 0.17246699333190918},
#   'product_kernel': {'train_error': np.float64(0.003629878329846287),
#    'test_error': np.float64(0.00582570005198867),
#    'time': 0.0012500286102294922},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009147226443167936),
#    'test_error': np.float64(0.0068767921351391755),
#    'time': 8.065603017807007},
#   'dkrl': {'train_error': np.float64(0.0019064795010899937),
#    'test_error': np.float64(0.004446882541057352),
#    'time': 0.15413236618041992},
#   'product_kernel': {'train_error': np.float64(0.003410766767575577),
#    'test_error': np.float64(0.006103780974912283),
#    'time': 0.0012149810791015625},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009959638079929759),
#    'test_error': np.float64(0.010671385026972315),
#    'time': 7.4108500480651855},
#   'dkrl': {'train_error': np.float64(0.0021776395972281943),
#    'test_error': np.float64(0.003322889793316657),
#    'time': 0.19628190994262695},
#   'product_kernel': {'train_error': np.float64(0.003678227789400156),
#    'test_error': np.float64(0.005596742085059076),
#    'time': 0.0010437965393066406},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009613913006046882),
#    'test_error': np.float64(0.010118391660115448),
#    'time': 7.551285028457642},
#   'dkrl': {'train_error': np.float64(0.003296627186354964),
#    'test_error': np.float64(0.009774449416197137),
#    'time': 0.1678938865661621},
#   'product_kernel': {'train_error': np.float64(0.0036953914758116753),
#    'test_error': np.float64(0.0066786743347450085),
#    'time': 0.0011870861053466797},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009471530075628322),
#    'test_error': np.float64(0.008620601769352258),
#    'time': 8.10480284690857},
#   'dkrl': {'train_error': np.float64(0.0021554217930570075),
#    'test_error': np.float64(0.0028707696016689664),
#    'time': 0.15653181076049805},
#   'product_kernel': {'train_error': np.float64(0.0034836014517370738),
#    'test_error': np.float64(0.004674997512944319),
#    'time': 0.001234292984008789},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00977981890024638),
#    'test_error': np.float64(0.008710360492666585),
#    'time': 7.850343942642212},
#   'dkrl': {'train_error': np.float64(0.0022094779824323673),
#    'test_error': np.float64(0.002970607612763991),
#    'time': 0.1808769702911377},
#   'product_kernel': {'train_error': np.float64(0.003619877884248441),
#    'test_error': np.float64(0.006504804896475937),
#    'time': 0.0019681453704833984},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00934542652717733),
#    'test_error': np.float64(0.009537013251341183),
#    'time': 7.531315088272095},
#   'dkrl': {'train_error': np.float64(0.002218314294242039),
#    'test_error': np.float64(0.00368405357229688),
#    'time': 0.1569380760192871},
#   'product_kernel': {'train_error': np.float64(0.003446627071583314),
#    'test_error': np.float64(0.006414269434932536),
#    'time': 0.0015790462493896484},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00933394284995398),
#    'test_error': np.float64(0.007916730218100134),
#    'time': 8.187848091125488},
#   'dkrl': {'train_error': np.float64(0.002112865897947867),
#    'test_error': np.float64(0.004066480249903599),
#    'time': 0.18045902252197266},
#   'product_kernel': {'train_error': np.float64(0.0035091090755003133),
#    'test_error': np.float64(0.006783761276447752),
#    'time': 0.0018208026885986328},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00977814107372162),
#    'test_error': np.float64(0.00633604961201431),
#    'time': 7.816213130950928},
#   'dkrl': {'train_error': np.float64(0.0023302368378596734),
#    'test_error': np.float64(0.003109302597756789),
#    'time': 0.15872907638549805},
#   'product_kernel': {'train_error': np.float64(0.0037731800440685605),
#    'test_error': np.float64(0.004821181952477323),
#    'time': 0.0015110969543457031},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009512424621858298),
#    'test_error': np.float64(0.008577832603661899),
#    'time': 7.664115905761719},
#   'dkrl': {'train_error': np.float64(0.0019396760418629512),
#    'test_error': np.float64(0.003173586363681927),
#    'time': 0.15664005279541016},
#   'product_kernel': {'train_error': np.float64(0.0035560597390233086),
#    'test_error': np.float64(0.005627702741110751),
#    'time': 0.0015943050384521484},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009355811821021399),
#    'test_error': np.float64(0.009458156577837397),
#    'time': 8.116683959960938},
#   'dkrl': {'train_error': np.float64(0.002129237622692042),
#    'test_error': np.float64(0.003082833515781181),
#    'time': 0.12904596328735352},
#   'product_kernel': {'train_error': np.float64(0.0037026469625522553),
#    'test_error': np.float64(0.007477148908290086),
#    'time': 0.0014011859893798828},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009262752733494183),
#    'test_error': np.float64(0.009613116596729579),
#    'time': 7.604626893997192},
#   'dkrl': {'train_error': np.float64(0.0023095837700984508),
#    'test_error': np.float64(0.005279447550102132),
#    'time': 0.19348716735839844},
#   'product_kernel': {'train_error': np.float64(0.0032874815575784414),
#    'test_error': np.float64(0.007583036671515192),
#    'time': 0.0014562606811523438},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009395707800977727),
#    'test_error': np.float64(0.008869866286241845),
#    'time': 7.952939987182617},
#   'dkrl': {'train_error': np.float64(0.0021037361850019306),
#    'test_error': np.float64(0.0038175296722253475),
#    'time': 0.13665509223937988},
#   'product_kernel': {'train_error': np.float64(0.0034853804632889057),
#    'test_error': np.float64(0.00598302313494702),
#    'time': 0.001291036605834961},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008837080392713258),
#    'test_error': np.float64(0.009796201888126238),
#    'time': 7.9267637729644775},
#   'dkrl': {'train_error': np.float64(0.0022449339362681743),
#    'test_error': np.float64(0.003782217426435428),
#    'time': 0.17645835876464844},
#   'product_kernel': {'train_error': np.float64(0.003493890559785148),
#    'test_error': np.float64(0.007411125992551952),
#    'time': 0.0012061595916748047},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009719442241773586),
#    'test_error': np.float64(0.009353547582072937),
#    'time': 7.792580842971802},
#   'dkrl': {'train_error': np.float64(0.0021190530071872648),
#    'test_error': np.float64(0.002928080595477336),
#    'time': 0.16872334480285645},
#   'product_kernel': {'train_error': np.float64(0.0036253012291800973),
#    'test_error': np.float64(0.005234047225672471),
#    'time': 0.0012040138244628906},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008626104222818),
#    'test_error': np.float64(0.008595978419953156),
#    'time': 8.228143692016602},
#   'dkrl': {'train_error': np.float64(0.0022122188815841327),
#    'test_error': np.float64(0.0027042932042833606),
#    'time': 0.15137195587158203},
#   'product_kernel': {'train_error': np.float64(0.0034251363856998857),
#    'test_error': np.float64(0.004298246322738301),
#    'time': 0.0012180805206298828},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009185385616347873),
#    'test_error': np.float64(0.009472784948890273),
#    'time': 9.63152813911438},
#   'dkrl': {'train_error': np.float64(0.002093613175819427),
#    'test_error': np.float64(0.0030929928278174016),
#    'time': 0.17639422416687012},
#   'product_kernel': {'train_error': np.float64(0.0036887585185318055),
#    'test_error': np.float64(0.005527659845911891),
#    'time': 0.0014140605926513672},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009403218709015762),
#    'test_error': np.float64(0.00927650005666603),
#    'time': 10.067716121673584},
#   'dkrl': {'train_error': np.float64(0.0021626478799612408),
#    'test_error': np.float64(0.004146128107637271),
#    'time': 0.21054482460021973},
#   'product_kernel': {'train_error': np.float64(0.003533217154113044),
#    'test_error': np.float64(0.006701781022268955),
#    'time': 0.0024073123931884766},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009853920479924849),
#    'test_error': np.float64(0.00817377864912173),
#    'time': 10.065462112426758},
#   'dkrl': {'train_error': np.float64(0.0019270048647518614),
#    'test_error': np.float64(0.0019882789533949507),
#    'time': 0.1642441749572754},
#   'product_kernel': {'train_error': np.float64(0.00392735069241388),
#    'test_error': np.float64(0.005264699811014269),
#    'time': 0.001219034194946289},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00895204384674437),
#    'test_error': np.float64(0.01065552516140483),
#    'time': 7.654892683029175},
#   'dkrl': {'train_error': np.float64(0.002348543974457186),
#    'test_error': np.float64(0.004082233919672799),
#    'time': 0.15935516357421875},
#   'product_kernel': {'train_error': np.float64(0.0035018790350464218),
#    'test_error': np.float64(0.007662027921375217),
#    'time': 0.0012438297271728516},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009827304451507684),
#    'test_error': np.float64(0.009188395667420978),
#    'time': 8.109719038009644},
#   'dkrl': {'train_error': np.float64(0.0022079192205474336),
#    'test_error': np.float64(0.0026172329567293886),
#    'time': 0.1592421531677246},
#   'product_kernel': {'train_error': np.float64(0.0036724885138199395),
#    'test_error': np.float64(0.005914397121981582),
#    'time': 0.0011911392211914062},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.00941752981312308),
#    'test_error': np.float64(0.010049296255244667),
#    'time': 8.567471742630005},
#   'dkrl': {'train_error': np.float64(0.002152629343523204),
#    'test_error': np.float64(0.00431659298095681),
#    'time': 0.17220187187194824},
#   'product_kernel': {'train_error': np.float64(0.003379165033267111),
#    'test_error': np.float64(0.0063302109086337734),
#    'time': 0.0011739730834960938},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.008615445988606935),
#    'test_error': np.float64(0.009407711580438145),
#    'time': 7.916771173477173},
#   'dkrl': {'train_error': np.float64(0.00228346449529738),
#    'test_error': np.float64(0.0028063607263097232),
#    'time': 0.15428614616394043},
#   'product_kernel': {'train_error': np.float64(0.0035709925380158288),
#    'test_error': np.float64(0.006345340385379314),
#    'time': 0.0015418529510498047},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009620281751168113),
#    'test_error': np.float64(0.010926108179136959),
#    'time': 7.7015061378479},
#   'dkrl': {'train_error': np.float64(0.002158805259580426),
#    'test_error': np.float64(0.0033494710561963654),
#    'time': 0.19385600090026855},
#   'product_kernel': {'train_error': np.float64(0.0036509396358931734),
#    'test_error': np.float64(0.007491318904356311),
#    'time': 0.0012331008911132812},
#   'rank': 2},
#  {'sin': {'train_error': np.float64(0.009115581002394584),
#    'test_error': np.float64(0.008823476423505339),
#    'time': 8.217555046081543},
#   'dkrl': {'train_error': np.float64(0.001962910029875763),
#    'test_error': np.float64(0.003038266529595355),
#    'time': 0.1789999008178711},
#   'product_kernel': {'train_error': np.float64(0.003611754967148892),
#    'test_error': np.float64(0.005516245253164978),
#    'time': 0.0012288093566894531},
#   'rank': 2}]

# %%
agg_results = {r: aggregate_results(all_results.item()[r]) for r in ranks}
print("Monte Carlo Simulation Results:")
for r, methods in agg_results.items():
    print(f"Rank: {r}")
    for method, metrics in methods.items():
        print(f"  Method: {method}")
        for key, value in metrics.items():
            print(f"    {key}: {value}")
            
# Save aggregated results to file
# output_errors_path = "./generated_data/dkrl/seed-0/bias-0.1/monte_carlo_results.npz"
# np.savez(output_errors_path, **agg_results)
# print("Saved Monte Carlo results to", output_errors_path)
# Out:
# Monte Carlo Simulation Results:
# Rank: 2
#   Method: sin
#     train_error_mean: 0.00937916095615329
#     train_error_std: 0.00038454278114945277
#     test_error_mean: 0.009462745829805419
#     test_error_std: 0.0011205739780943541
#     time_mean: 7.936088354587555
#     time_std: 0.4857740014973078
#   Method: dkrl
#     train_error_mean: 0.002166362986008461
#     train_error_std: 0.0001569218033584007
#     test_error_mean: 0.0034764919432422963
#     test_error_std: 0.0009231128617741357
#     time_mean: 0.17393542766571046
#     time_std: 0.030530398664730552
#   Method: product_kernel
#     train_error_mean: 0.003599158331717038
#     train_error_std: 0.00014698800956748469
#     test_error_mean: 0.006195401018891331
#     test_error_std: 0.0009716191861327476
#     time_mean: 0.0013425326347351074
#     time_std: 0.00020505553146355168
# Rank: 3
#   Method: sin
#     train_error_mean: 0.008526758314372721
#     train_error_std: 0.0003981503190999347
#     test_error_mean: 0.008505851492291815
#     test_error_std: 0.001099655185031159
#     time_mean: 8.09288063287735
#     time_std: 0.3153291318032026
#   Method: dkrl
#     train_error_mean: 0.0024568382882485733
#     train_error_std: 0.00018113179061526608
#     test_error_mean: 0.004661651331985493
#     test_error_std: 0.0009757445923716303
#     time_mean: 0.4702348256111145
#     time_std: 0.10936676418127553
#   Method: product_kernel
#     train_error_mean: 0.00435972905477934
#     train_error_std: 0.00016679019396686492
#     test_error_mean: 0.00749062770869782
#     test_error_std: 0.0011999489546645778
#     time_mean: 0.0014012837409973144
#     time_std: 0.0002659716158978367
# Rank: 5
#   Method: sin
#     train_error_mean: 0.011855325427909529
#     train_error_std: 0.0004766762556197946
#     test_error_mean: 0.011960942825122459
#     test_error_std: 0.0014467261570653555
#     time_mean: 7.998271207809449
#     time_std: 0.49509400418957455
#   Method: dkrl
#     train_error_mean: 0.0027409155766663063
#     train_error_std: 0.00010669330037130967
#     test_error_mean: 0.0075510646236532615
#     test_error_std: 0.00122412523076192
#     time_mean: 1.6868174648284913
#     time_std: 0.39071688922064585
#   Method: product_kernel
#     train_error_mean: 0.005715873276539989
#     train_error_std: 0.00019527211606806637
#     test_error_mean: 0.010008492283299454
#     test_error_std: 0.0014013701730015437
#     time_mean: 0.001438899040222168
#     time_std: 0.0003714460651599196
# Rank: 10
#   Method: sin
#     train_error_mean: 0.017455373270624186
#     train_error_std: 0.0007290135407045265
#     test_error_mean: 0.017544021370505692
#     test_error_std: 0.0018159586090776233
#     time_mean: 8.115052132606506
#     time_std: 0.4709212336959319
#   Method: dkrl
#     train_error_mean: 0.0026359632358221607
#     train_error_std: 7.394670341934381e-05
#     test_error_mean: 0.012799418294242535
#     test_error_std: 0.0017338703741417998
#     time_mean: 7.951814560890198
#     time_std: 0.8747160751723501
#   Method: product_kernel
#     train_error_mean: 0.008281288620885762
#     train_error_std: 0.00026780853702087424
#     test_error_mean: 0.014670080258680657
#     test_error_std: 0.0017494421865559776
#     time_mean: 0.0017470932006835938
#     time_std: 0.0003652295743292798

# %%
import pandas as pd

# Define the metrics for each rank.
metrics = ["Train Error Mean", "Train Error Std", "Test Error Mean", "Test Error Std", "Time Mean", "Time Std"]

# Extract the sorted ranks
ranks = sorted(agg_results.keys())

# Create a MultiIndex for the columns: first level = rank, second level = metric
columns = pd.MultiIndex.from_product([ranks, metrics], names=["Rank", "Metric"])

# Assume that all ranks have the same set of methods.
methods = list(agg_results[ranks[0]].keys())

# Build a dictionary where each key is a method and its value is a list of metric values.
data = {}
for method in methods:
    row_values = []
    for r in ranks:
        metrics_data = agg_results[r][method]
        row_values.append(metrics_data["train_error_mean"])
        row_values.append(metrics_data["train_error_std"])
        row_values.append(metrics_data["test_error_mean"])
        row_values.append(metrics_data["test_error_std"])
        row_values.append(metrics_data["time_mean"])
        row_values.append(metrics_data["time_std"])
    data[method] = row_values

# Create a DataFrame with methods as rows and our MultiIndex columns.
df = pd.DataFrame.from_dict(data, orient="index", columns=columns)

df.to_csv('asos-output.csv', index=False)
